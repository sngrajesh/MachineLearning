# %%
import numpy as np

# %%
x = np.array([2,5,7,8,9,10,23,45])
y = np.array([13, 15, 20, 34, 36, 56, 66, 78])

# %%
n = len(x)
x_sum = x.sum()
y_sum = y.sum()

# %%
xy_prod_sum = (x*y).sum()

x_sum_sq = (x_sum ** 2)/n
x_sq_sum = (x ** 2).sum()

# %% [markdown]
# ### Manual Linear Regression Calculation
#
# - **Slope (b1)**: Calculated using the formula:
# ```
# b1 = (x_sum * y_sum / n - xy_prod_sum) / (x_sum_sq - x_sq_sum)
# ```
#
# - **Intercept (b0)**: Using:
# ```
# b0 = (y_sum - (b1 * x_sum)) / n
# ```

# %%
b1 = ((x_sum * y_sum * 1/n) - xy_prod_sum)/ (x_sum_sq - x_sq_sum)
b1
# Out:
# 1.5031881454872025

# %%
b0 = ((y_sum) - (b1*x_sum))/n
b0
# Out:
# 19.269061517736866

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(x.reshape(-1, 1), y)
# Out:
# LinearRegression()

# %%
lr.intercept_, lr.coef_
# Out:
# (19.269061517736862, array([1.50318815]))
