# %%
import sklearn
import numpy as np
import pandas as pd
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.compose import ColumnTransformer
from sklearn.compose import make_column_transformer, make_column_selector
from sklearn.metrics import accuracy_score, r2_score, classification_report, roc_auc_score


import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r'C:\Users\DAI.STUDENTSDC\Desktop\Machine Learning\Data Sets\loan.csv')
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# 1               4583             1508.0       128.0             360.0
# 2               3000                0.0        66.0             360.0
# 3               2583             2358.0       120.0             360.0
# 4               6000                0.0       141.0             360.0
# ..               ...                ...         ...               ...
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 0               1.0         Urban           Y
# 1               1.0         Rural           N
# 2               1.0         Urban           Y
# 3               1.0         Urban           Y
# 4               1.0         Urban           Y
# ..              ...           ...         ...
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# 611             1.0         Urban           Y
# 612             1.0         Urban           Y
# 613             0.0     Semiurban           N
#
# [614 rows x 13 columns]

# %%
df.set_index('Loan_ID', inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 614 entries, LP001002 to LP002990
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             601 non-null    object
#  1   Married            611 non-null    object
#  2   Dependents         599 non-null    object
#  3   Education          614 non-null    object
#  4   Self_Employed      582 non-null    object
#  5   ApplicantIncome    614 non-null    int64
#  6   CoapplicantIncome  614 non-null    float64
#  7   LoanAmount         592 non-null    float64
#  8   Loan_Amount_Term   600 non-null    float64
#  9   Credit_History     564 non-null    float64
#  10  Property_Area      614 non-null    object
#  11  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(7)
# memory usage: 62.4+ KB

# %%
X = df.drop(['Loan_Status'], axis=1)
y = df['Loan_Status']

# %%
X_train , X_test , y_train , y_test = train_test_split(X , y , test_size = 0.2 , random_state = 0)

# %%
num_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median'))
])

cat_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='constant', fill_value='missing')),
    ('onehot', OneHotEncoder(drop='first', handle_unknown='ignore'))
])

preprocessor = ColumnTransformer(
    transformers=[
        ('num', num_transformer, make_column_selector(dtype_include=[int, float])),
        ('cat', cat_transformer, make_column_selector(dtype_include=object))
    ],
    remainder='passthrough'
)

# Define the full pipeline with logistic regression
pipe = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('classifier', LogisticRegression(max_iter=200))
])

# Parameter grid for logistic regression solvers
params = {
    'classifier__solver': [
        'lbfgs',
        'liblinear',
        'newton-cg',
        'newton-cholesky',
        'sag'
    ]
}

kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=24)


# Apply GridSearchCV
gcv = GridSearchCV(pipe, param_grid=params, cv=kfold, error_score='raise')
gcv.fit(X_train, y_train)


# Output best parameters and scores
print("Best Parameters:", gcv.best_params_)
print("Best Cross-Validation Score:", gcv.best_score_)

# Test set predictions and performance
y_pred = gcv.predict(X_test)
print("Test Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Best Parameters: {'classifier__solver': 'lbfgs'}
# Best Cross-Validation Score: 0.8043083900226756
# Test Accuracy: 0.8373983739837398
# Classification Report:
#                precision    recall  f1-score   support
#
#            N       0.88      0.45      0.60        33
#            Y       0.83      0.98      0.90        90
#
#     accuracy                           0.84       123
#    macro avg       0.86      0.72      0.75       123
# weighted avg       0.84      0.84      0.82       123

# %%
best_model=gcv.best_estimator_
y_pred = best_model.predict(X_test)
y_pred_proba = best_model.predict_proba(X_test)
y_pred_proba = y_pred_proba[:, 1]

print("\naccuracy_scor: ", accuracy_score(y_test, y_pred))
print("\nclassification_report: \n", classification_report(y_test, y_pred))
print("\nroc_auc_score: ", roc_auc_score(y_test, y_pred_proba))
# Out:
# accuracy_scor:  0.8373983739837398
#
# classification_report:
#                precision    recall  f1-score   support
#
#            N       0.88      0.45      0.60        33
#            Y       0.83      0.98      0.90        90
#
#     accuracy                           0.84       123
#    macro avg       0.86      0.72      0.75       123
# weighted avg       0.84      0.84      0.82       123
#
#
# roc_auc_score:  0.7932659932659932

# %% [markdown]
# ---
# Logistic Regression

# %%
df.head()
# Out:
#          Gender Married Dependents     Education Self_Employed  \
# Loan_ID
# LP001002   Male      No          0      Graduate            No
# LP001003   Male     Yes          1      Graduate            No
# LP001005   Male     Yes          0      Graduate           Yes
# LP001006   Male     Yes          0  Not Graduate            No
# LP001008   Male      No          0      Graduate            No
#
#           ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# Loan_ID
# LP001002             5849                0.0         NaN             360.0
# LP001003             4583             1508.0       128.0             360.0
# LP001005             3000                0.0        66.0             360.0
# LP001006             2583             2358.0       120.0             360.0
# LP001008             6000                0.0       141.0             360.0
#
#           Credit_History Property_Area Loan_Status
# Loan_ID
# LP001002             1.0         Urban           Y
# LP001003             1.0         Rural           N
# LP001005             1.0         Urban           Y
# LP001006             1.0         Urban           Y
# LP001008             1.0         Urban           Y

# %%
#Sir
loan = df.drop('Loan_Status', axis=1)

# %%
#Sir
#Testing

imp_cat = SimpleImputer(strategy='constant', fill_value="unknown").set_output(transform="pandas")
imp_num = SimpleImputer(strategy="median").set_output(transform="pandas")
trans_imp = make_column_transformer((imp_cat, make_column_selector(dtype_include=object)),
                                  (imp_num, make_column_selector(dtype_exclude=object)),
                                    verbose_feature_names_out=False)

trans_imp = trans_imp.set_output(transform='pandas')

loan_imp = trans_imp.fit_transform(loan)
print(loan_imp.isnull().sum().sum())
print(loan_imp.columns)
# Out:
# 0
# Index(['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
#        'Property_Area', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History'],
#       dtype='object')

# %%
######
ohe = OneHotEncoder(handle_unknown='ignore',sparse_output=False, drop='first').set_output(transform='pandas')
trans_ohe = make_column_transformer((ohe, make_column_selector(dtype_include=object)),
                                    ('passthrough', make_column_selector(dtype_exclude=object)),
                                      verbose_feature_names_out=False)

# trans_ohe = trans_ohe.set_output(transform='pandas')

# X_imp_ohe trans_ohe.fit_transform(X_imp)
# X_imp_ohe.dtypes

# %%
lr = LogisticRegression(random_state=24)

pipe = Pipeline([('IMP', trans_imp), ('OHE', trans_ohe), ('LR', lr)])
kfold = StratifiedKFold(n_splits=5, random_state= 24, shuffle= True)
params = {'LR__solver': ['lbfgs", "liblinear', 'newton-cg', 'newton-cholesky', 'sag', 'saga']}
gcv = GridSearchCV(pipe, param_grid=params, scoring ='roc_auc', cv=kfold, verbose=3)

gcv.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# [CV 1/5] END .......LR__solver=lbfgs", "liblinear;, score=nan total time=   0.0s
# [CV 2/5] END .......LR__solver=lbfgs", "liblinear;, score=nan total time=   0.0s
# [CV 3/5] END .......LR__solver=lbfgs", "liblinear;, score=nan total time=   0.0s
# [CV 4/5] END .......LR__solver=lbfgs", "liblinear;, score=nan total time=   0.0s
# [CV 5/5] END .......LR__solver=lbfgs", "liblinear;, score=nan total time=   0.0s
# [CV 1/5] END ..............LR__solver=newton-cg;, score=0.846 total time=   0.0s
# [CV 2/5] END ..............LR__solver=newton-cg;, score=0.702 total time=   0.0s
# [CV 3/5] END ..............LR__solver=newton-cg;, score=0.816 total time=   0.0s
# [CV 4/5] END ..............LR__solver=newton-cg;, score=0.719 total time=   0.0s
# [CV 5/5] END ..............LR__solver=newton-cg;, score=0.608 total time=   0.0s
# [CV 1/5] END ........LR__solver=newton-cholesky;, score=0.846 total time=   0.0s
# [CV 2/5] END ........LR__solver=newton-cholesky;, score=0.702 total time=   0.0s
# [CV 3/5] END ........LR__solver=newton-cholesky;, score=0.816 total time=   0.0s
# [CV 4/5] END ........LR__solver=newton-cholesky;, score=0.719 total time=   0.0s
# [CV 5/5] END ........LR__solver=newton-cholesky;, score=0.608 total time=   0.0s
# [CV 1/5] END ....................LR__solver=sag;, score=0.421 total time=   0.0s
# [CV 2/5] END ....................LR__solver=sag;, score=0.484 total time=   0.0s
# [CV 3/5] END ....................LR__solver=sag;, score=0.431 total time=   0.0s
# [CV 4/5] END ....................LR__solver=sag;, score=0.540 total time=   0.0s
# [CV 5/5] END ....................LR__solver=sag;, score=0.533 total time=   0.0s
# [CV 1/5] END ...................LR__solver=saga;, score=0.435 total time=   0.0s
# [CV 2/5] END ...................LR__solver=saga;, score=0.493 total time=   0.0s
# [CV 3/5] END ...................LR__solver=saga;, score=0.455 total time=   0.0s
# [CV 4/5] END ...................LR__solver=saga;, score=0.545 total time=   0.0s
# [CV 5/5] END ...................LR__solver=saga;, score=0.544 total time=   0.0s
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=24, shuffle=True),
#              estimator=Pipeline(steps=[('IMP',
#                                         ColumnTransformer(transformers=[('simpleimputer-1',
#                                                                          SimpleImputer(fill_value='unknown',
#                                                                                        strategy='constant'),
#                                                                          <sklearn.compose._column_transformer.make_column_selector object at 0x00000283D937CBC0>),
#                                                                         ('simpleimputer-2',
#                                                                          SimpleImputer(strategy='median')...
#                                                                          <sklearn.compose._column_transformer.make_column_selector object at 0x00000283D93BBD10>),
#                                                                         ('passthrough',
#                                                                          'passthrough',
#                                                                          <sklearn.compose._column_transformer.make_column_selector object at 0x00000283D93B8440>)],
#                                                           verbose_feature_names_out=False)),
#                                        ('LR',
#                                         LogisticRegression(random_state=24))]),
#              param_grid={'LR__solver': ['lbfgs", "liblinear', 'newton-cg',
#                                         'newton-cholesky', 'sag', 'saga']},
#              scoring='roc_auc', verbose=3)

# %%
print(gcv.best_params_)
print(gcv.best_score_)
# Out:
# {'LR__solver': 'newton-cg'}
# 0.7381164193694285

# %%
best_model=gcv.best_estimator_

# %%
y_pred = best_model.predict(X_test)

# %%
y_pred_proba = best_model.predict_proba(X_test)
y_pred_proba = y_pred_proba[:, 1] #roc_auc_score: Takes y_test and the predicted probabilities (y_pred_proba) for the positive class.

# %%
print("\naccuracy_scor: ", accuracy_score(y_test, y_pred))
print("\nclassification_report: \n", classification_report(y_test, y_pred))
print("\nroc_auc_score: ", roc_auc_score(y_test, y_pred_proba))
# Out:
# accuracy_scor:  0.8373983739837398
#
# classification_report:
#                precision    recall  f1-score   support
#
#            N       0.88      0.45      0.60        33
#            Y       0.83      0.98      0.90        90
#
#     accuracy                           0.84       123
#    macro avg       0.86      0.72      0.75       123
# weighted avg       0.84      0.84      0.82       123
#
#
# roc_auc_score:  0.81986531986532

# %% [markdown]
# ---
# KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import MinMaxScaler, StandardScaler

imp_cat = SimpleImputer(
  strategy='constant', 
  fill_value="unknown"
).set_output(transform="pandas")

imp_num = SimpleImputer(
  strategy="median"
).set_output(transform="pandas") 

trans_imp = make_column_transformer(
  (imp_cat, make_column_selector(dtype_include=object)),
  (imp_num, make_column_selector(dtype_exclude=object)),
  verbose_feature_names_out=False
).set_output(transform='pandas')

scale_mm = MinMaxScaler()
scale_std = StandardScaler()

ohe = OneHotEncoder(handle_unknown='ignore',sparse_output=False, drop='first').set_output(transform='pandas')
trans_ohe = make_column_transformer((ohe, make_column_selector(dtype_include=object)),
                                    ('passthrough', make_column_selector(dtype_exclude=object)),
                                      verbose_feature_names_out=False)

knn = KNeighborsClassifier()

pipe = Pipeline([
    ('IMP', trans_imp), 
    ('OHE', trans_ohe),
    ('SCL' ,None),
    ('KNN', knn)
])

kfold = StratifiedKFold(n_splits=5, random_state= 24, shuffle= True)
params = {
    'KNN__n_neighbors': np.arange(1, 30, 3),
    'SCL' : [None, scale_mm, scale_std],
}
gcv = GridSearchCV(pipe, param_grid=params, scoring ='roc_auc', cv=kfold, verbose=3)

gcv.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# [CV 1/5] END ......KNN__n_neighbors=1, SCL=None;, score=0.538 total time=   0.0s
# [CV 2/5] END ......KNN__n_neighbors=1, SCL=None;, score=0.506 total time=   0.0s
# [CV 3/5] END ......KNN__n_neighbors=1, SCL=None;, score=0.513 total time=   0.0s
# [CV 4/5] END ......KNN__n_neighbors=1, SCL=None;, score=0.450 total time=   0.0s
# [CV 5/5] END ......KNN__n_neighbors=1, SCL=None;, score=0.511 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=1, SCL=MinMaxScaler();, score=0.754 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=1, SCL=MinMaxScaler();, score=0.549 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=1, SCL=MinMaxScaler();, score=0.698 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=1, SCL=MinMaxScaler();, score=0.673 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=1, SCL=MinMaxScaler();, score=0.597 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=1, SCL=StandardScaler();, score=0.801 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=1, SCL=StandardScaler();, score=0.565 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=1, SCL=StandardScaler();, score=0.721 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=1, SCL=StandardScaler();, score=0.650 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=1, SCL=StandardScaler();, score=0.559 total time=   0.0s
# [CV 1/5] END ......KNN__n_neighbors=4, SCL=None;, score=0.457 total time=   0.0s
# [CV 2/5] END ......KNN__n_neighbors=4, SCL=None;, score=0.488 total time=   0.0s
# [CV 3/5] END ......KNN__n_neighbors=4, SCL=None;, score=0.538 total time=   0.0s
# [CV 4/5] END ......KNN__n_neighbors=4, SCL=None;, score=0.471 total time=   0.0s
# [CV 5/5] END ......KNN__n_neighbors=4, SCL=None;, score=0.529 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=4, SCL=MinMaxScaler();, score=0.766 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=4, SCL=MinMaxScaler();, score=0.577 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=4, SCL=MinMaxScaler();, score=0.747 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=4, SCL=MinMaxScaler();, score=0.636 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=4, SCL=MinMaxScaler();, score=0.605 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=4, SCL=StandardScaler();, score=0.829 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=4, SCL=StandardScaler();, score=0.633 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=4, SCL=StandardScaler();, score=0.761 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=4, SCL=StandardScaler();, score=0.694 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=4, SCL=StandardScaler();, score=0.549 total time=   0.0s
# [CV 1/5] END ......KNN__n_neighbors=7, SCL=None;, score=0.554 total time=   0.0s
# [CV 2/5] END ......KNN__n_neighbors=7, SCL=None;, score=0.563 total time=   0.0s
# [CV 3/5] END ......KNN__n_neighbors=7, SCL=None;, score=0.588 total time=   0.0s
# [CV 4/5] END ......KNN__n_neighbors=7, SCL=None;, score=0.434 total time=   0.0s
# [CV 5/5] END ......KNN__n_neighbors=7, SCL=None;, score=0.518 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=7, SCL=MinMaxScaler();, score=0.746 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=7, SCL=MinMaxScaler();, score=0.604 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=7, SCL=MinMaxScaler();, score=0.709 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=7, SCL=MinMaxScaler();, score=0.646 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=7, SCL=MinMaxScaler();, score=0.636 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=7, SCL=StandardScaler();, score=0.818 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=7, SCL=StandardScaler();, score=0.656 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=7, SCL=StandardScaler();, score=0.795 total time=   0.1s
# [CV 4/5] END KNN__n_neighbors=7, SCL=StandardScaler();, score=0.695 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=7, SCL=StandardScaler();, score=0.569 total time=   0.0s
# [CV 1/5] END .....KNN__n_neighbors=10, SCL=None;, score=0.524 total time=   0.0s
# [CV 2/5] END .....KNN__n_neighbors=10, SCL=None;, score=0.561 total time=   0.0s
# [CV 3/5] END .....KNN__n_neighbors=10, SCL=None;, score=0.662 total time=   0.0s
# [CV 4/5] END .....KNN__n_neighbors=10, SCL=None;, score=0.477 total time=   0.0s
# [CV 5/5] END .....KNN__n_neighbors=10, SCL=None;, score=0.540 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=10, SCL=MinMaxScaler();, score=0.767 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=10, SCL=MinMaxScaler();, score=0.663 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=10, SCL=MinMaxScaler();, score=0.730 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=10, SCL=MinMaxScaler();, score=0.625 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=10, SCL=MinMaxScaler();, score=0.635 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=10, SCL=StandardScaler();, score=0.801 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=10, SCL=StandardScaler();, score=0.683 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=10, SCL=StandardScaler();, score=0.777 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=10, SCL=StandardScaler();, score=0.740 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=10, SCL=StandardScaler();, score=0.617 total time=   0.0s
# [CV 1/5] END .....KNN__n_neighbors=13, SCL=None;, score=0.598 total time=   0.0s
# [CV 2/5] END .....KNN__n_neighbors=13, SCL=None;, score=0.575 total time=   0.0s
# [CV 3/5] END .....KNN__n_neighbors=13, SCL=None;, score=0.673 total time=   0.0s
# [CV 4/5] END .....KNN__n_neighbors=13, SCL=None;, score=0.490 total time=   0.0s
# [CV 5/5] END .....KNN__n_neighbors=13, SCL=None;, score=0.562 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=13, SCL=MinMaxScaler();, score=0.778 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=13, SCL=MinMaxScaler();, score=0.695 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=13, SCL=MinMaxScaler();, score=0.743 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=13, SCL=MinMaxScaler();, score=0.654 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=13, SCL=MinMaxScaler();, score=0.616 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=13, SCL=StandardScaler();, score=0.807 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=13, SCL=StandardScaler();, score=0.684 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=13, SCL=StandardScaler();, score=0.788 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=13, SCL=StandardScaler();, score=0.732 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=13, SCL=StandardScaler();, score=0.640 total time=   0.0s
# [CV 1/5] END .....KNN__n_neighbors=16, SCL=None;, score=0.586 total time=   0.0s
# [CV 2/5] END .....KNN__n_neighbors=16, SCL=None;, score=0.524 total time=   0.0s
# [CV 3/5] END .....KNN__n_neighbors=16, SCL=None;, score=0.607 total time=   0.0s
# [CV 4/5] END .....KNN__n_neighbors=16, SCL=None;, score=0.498 total time=   0.0s
# [CV 5/5] END .....KNN__n_neighbors=16, SCL=None;, score=0.574 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=16, SCL=MinMaxScaler();, score=0.796 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=16, SCL=MinMaxScaler();, score=0.698 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=16, SCL=MinMaxScaler();, score=0.755 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=16, SCL=MinMaxScaler();, score=0.656 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=16, SCL=MinMaxScaler();, score=0.638 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=16, SCL=StandardScaler();, score=0.814 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=16, SCL=StandardScaler();, score=0.690 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=16, SCL=StandardScaler();, score=0.793 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=16, SCL=StandardScaler();, score=0.728 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=16, SCL=StandardScaler();, score=0.642 total time=   0.0s
# [CV 1/5] END .....KNN__n_neighbors=19, SCL=None;, score=0.565 total time=   0.0s
# [CV 2/5] END .....KNN__n_neighbors=19, SCL=None;, score=0.523 total time=   0.0s
# [CV 3/5] END .....KNN__n_neighbors=19, SCL=None;, score=0.586 total time=   0.0s
# [CV 4/5] END .....KNN__n_neighbors=19, SCL=None;, score=0.477 total time=   0.0s
# [CV 5/5] END .....KNN__n_neighbors=19, SCL=None;, score=0.584 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=19, SCL=MinMaxScaler();, score=0.789 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=19, SCL=MinMaxScaler();, score=0.678 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=19, SCL=MinMaxScaler();, score=0.747 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=19, SCL=MinMaxScaler();, score=0.660 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=19, SCL=MinMaxScaler();, score=0.598 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=19, SCL=StandardScaler();, score=0.813 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=19, SCL=StandardScaler();, score=0.716 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=19, SCL=StandardScaler();, score=0.790 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=19, SCL=StandardScaler();, score=0.719 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=19, SCL=StandardScaler();, score=0.618 total time=   0.0s
# [CV 1/5] END .....KNN__n_neighbors=22, SCL=None;, score=0.567 total time=   0.0s
# [CV 2/5] END .....KNN__n_neighbors=22, SCL=None;, score=0.515 total time=   0.0s
# [CV 3/5] END .....KNN__n_neighbors=22, SCL=None;, score=0.612 total time=   0.0s
# [CV 4/5] END .....KNN__n_neighbors=22, SCL=None;, score=0.477 total time=   0.0s
# [CV 5/5] END .....KNN__n_neighbors=22, SCL=None;, score=0.533 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=22, SCL=MinMaxScaler();, score=0.798 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=22, SCL=MinMaxScaler();, score=0.689 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=22, SCL=MinMaxScaler();, score=0.748 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=22, SCL=MinMaxScaler();, score=0.689 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=22, SCL=MinMaxScaler();, score=0.607 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=22, SCL=StandardScaler();, score=0.819 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=22, SCL=StandardScaler();, score=0.725 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=22, SCL=StandardScaler();, score=0.812 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=22, SCL=StandardScaler();, score=0.736 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=22, SCL=StandardScaler();, score=0.614 total time=   0.0s
# [CV 1/5] END .....KNN__n_neighbors=25, SCL=None;, score=0.546 total time=   0.0s
# [CV 2/5] END .....KNN__n_neighbors=25, SCL=None;, score=0.494 total time=   0.0s
# [CV 3/5] END .....KNN__n_neighbors=25, SCL=None;, score=0.575 total time=   0.0s
# [CV 4/5] END .....KNN__n_neighbors=25, SCL=None;, score=0.479 total time=   0.0s
# [CV 5/5] END .....KNN__n_neighbors=25, SCL=None;, score=0.544 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=25, SCL=MinMaxScaler();, score=0.813 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=25, SCL=MinMaxScaler();, score=0.691 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=25, SCL=MinMaxScaler();, score=0.755 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=25, SCL=MinMaxScaler();, score=0.694 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=25, SCL=MinMaxScaler();, score=0.594 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=25, SCL=StandardScaler();, score=0.840 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=25, SCL=StandardScaler();, score=0.721 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=25, SCL=StandardScaler();, score=0.825 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=25, SCL=StandardScaler();, score=0.703 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=25, SCL=StandardScaler();, score=0.579 total time=   0.0s
# [CV 1/5] END .....KNN__n_neighbors=28, SCL=None;, score=0.535 total time=   0.0s
# [CV 2/5] END .....KNN__n_neighbors=28, SCL=None;, score=0.493 total time=   0.0s
# [CV 3/5] END .....KNN__n_neighbors=28, SCL=None;, score=0.558 total time=   0.0s
# [CV 4/5] END .....KNN__n_neighbors=28, SCL=None;, score=0.457 total time=   0.0s
# [CV 5/5] END .....KNN__n_neighbors=28, SCL=None;, score=0.481 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=28, SCL=MinMaxScaler();, score=0.810 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=28, SCL=MinMaxScaler();, score=0.715 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=28, SCL=MinMaxScaler();, score=0.771 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=28, SCL=MinMaxScaler();, score=0.738 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=28, SCL=MinMaxScaler();, score=0.589 total time=   0.0s
# [CV 1/5] END KNN__n_neighbors=28, SCL=StandardScaler();, score=0.843 total time=   0.0s
# [CV 2/5] END KNN__n_neighbors=28, SCL=StandardScaler();, score=0.692 total time=   0.0s
# [CV 3/5] END KNN__n_neighbors=28, SCL=StandardScaler();, score=0.837 total time=   0.0s
# [CV 4/5] END KNN__n_neighbors=28, SCL=StandardScaler();, score=0.688 total time=   0.0s
# [CV 5/5] END KNN__n_neighbors=28, SCL=StandardScaler();, score=0.603 total time=   0.0s
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=24, shuffle=True),
#              estimator=Pipeline(steps=[('IMP',
#                                         ColumnTransformer(transformers=[('simpleimputer-1',
#                                                                          SimpleImputer(fill_value='unknown',
#                                                                                        strategy='constant'),
#                                                                          <sklearn.compose._column_transformer.make_column_selector object at 0x00000283D9DF6540>),
#                                                                         ('simpleimputer-2',
#                                                                          SimpleImputer(strategy='median')...
#                                                                          <sklearn.compose._column_transformer.make_column_selector object at 0x00000283D9DF4CE0>),
#                                                                         ('passthrough',
#                                                                          'passthrough',
#                                                                          <sklearn.compose._column_transformer.make_column_selector object at 0x00000283D9DF4E60>)],
#                                                           verbose_feature_names_out=False)),
#                                        ('SCL', None),
#                                        ('KNN', KNeighborsClassifier())]),
#              param_grid={'KNN__n_neighbors': array([ 1,  4,  7, 10, 13, 16, 19, 22, 25, 28]),
#                          'SCL': [None, MinMaxScaler(), StandardScaler()]},
#              scoring='roc_auc', verbose=3)

# %%
gcv.best_score_, gcv.best_params_
# Out:
# (0.741161745342204, {'KNN__n_neighbors': 22, 'SCL': StandardScaler()})
