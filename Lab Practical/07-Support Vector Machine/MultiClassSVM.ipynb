# %% [markdown]
# SVM
# - Binary Classification
# - Multi-class Classification
#   - One-vs-One
#   - One-vs-All

# %%
import sklearn
import numpy as np
import pandas as pd
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, r2_score, roc_auc_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split
from sklearn.metrics import log_loss

from sklearn.preprocessing import MinMaxScaler
from sklearn.svm import SVC
from sklearn.compose import make_column_selector, make_column_transformer

# %%
df = pd.read_csv(r'C:\Users\DAI.STUDENTSDC\Desktop\Machine Learning\Data Sets\Cases\Satellite Imaging\Satellite.csv', sep=';')

X = df.drop(['classes'], axis=1)
y = df['classes']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=24)

# %% [markdown]
# Linear

# %%
svm = SVC(kernel='linear', probability=True,random_state=24, decision_function_shape='ovo')
scale_std = MinMaxScaler()
pipe = Pipeline([
    # ('CT', ct),
    ('SCL', scale_std),
    ('SVC', svm)
])

# %%
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('SCL', MinMaxScaler()),
#                 ('SVC',
#                  SVC(decision_function_shape='ovo', kernel='linear',
#                      probability=True, random_state=24))])

# %%
y_pred_proba = pipe.predict_proba(X_test)
print(log_loss(y_test, y_pred_proba))
# Out:
# 0.3446049113759542

# %% [markdown]
# Linear GridsearchCV

# %%
svm = SVC(kernel='linear', probability=True,random_state=24)
scale_mm = MinMaxScaler()
pipe = Pipeline([
    ('SCL', scale_mm),
    ('SVM', svm)
])

kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=24)
params = {
    'SVM__C': np.linspace(0.001, 5, 3),
    'SVM__decision_function_shape': ['ovo', 'ovr']
}

gcv = GridSearchCV(estimator=pipe, param_grid=params, scoring='neg_log_loss', cv=kfold, verbose=3)

# %%
gcv.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [CV 1/5] END SVM__C=0.001, SVM__decision_function_shape=ovo;, score=-0.560 total time=   5.2s
# [CV 2/5] END SVM__C=0.001, SVM__decision_function_shape=ovo;, score=-0.565 total time=   5.1s
# [CV 3/5] END SVM__C=0.001, SVM__decision_function_shape=ovo;, score=-0.536 total time=   5.5s
# [CV 4/5] END SVM__C=0.001, SVM__decision_function_shape=ovo;, score=-0.506 total time=   5.2s
# [CV 5/5] END SVM__C=0.001, SVM__decision_function_shape=ovo;, score=-0.540 total time=   5.1s
# [CV 1/5] END SVM__C=0.001, SVM__decision_function_shape=ovr;, score=-0.560 total time=   5.5s
# [CV 2/5] END SVM__C=0.001, SVM__decision_function_shape=ovr;, score=-0.565 total time=   5.6s
# [CV 3/5] END SVM__C=0.001, SVM__decision_function_shape=ovr;, score=-0.536 total time=   5.2s
# [CV 4/5] END SVM__C=0.001, SVM__decision_function_shape=ovr;, score=-0.506 total time=   5.4s
# [CV 5/5] END SVM__C=0.001, SVM__decision_function_shape=ovr;, score=-0.540 total time=   5.5s
# [CV 1/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovo;, score=-0.360 total time=   1.0s
# [CV 2/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovo;, score=-0.341 total time=   1.0s
# [CV 3/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovo;, score=-0.324 total time=   1.0s
# [CV 4/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovo;, score=-0.324 total time=   0.9s
# [CV 5/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovo;, score=-0.347 total time=   0.9s
# [CV 1/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovr;, score=-0.360 total time=   0.9s
# [CV 2/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovr;, score=-0.341 total time=   0.9s
# [CV 3/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovr;, score=-0.324 total time=   0.9s
# [CV 4/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovr;, score=-0.324 total time=   0.9s
# [CV 5/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovr;, score=-0.347 total time=   0.9s
# [CV 1/5] END SVM__C=5.0, SVM__decision_function_shape=ovo;, score=-0.362 total time=   1.0s
# [CV 2/5] END SVM__C=5.0, SVM__decision_function_shape=ovo;, score=-0.339 total time=   1.0s
# [CV 3/5] END SVM__C=5.0, SVM__decision_function_shape=ovo;, score=-0.326 total time=   1.0s
# [CV 4/5] END SVM__C=5.0, SVM__decision_function_shape=ovo;, score=-0.323 total time=   1.0s
# [CV 5/5] END SVM__C=5.0, SVM__decision_function_shape=ovo;, score=-0.343 total time=   1.1s
# [CV 1/5] END SVM__C=5.0, SVM__decision_function_shape=ovr;, score=-0.362 total time=   1.2s
# [CV 2/5] END SVM__C=5.0, SVM__decision_function_shape=ovr;, score=-0.339 total time=   1.0s
# [CV 3/5] END SVM__C=5.0, SVM__decision_function_shape=ovr;, score=-0.326 total time=   1.0s
# [CV 4/5] END SVM__C=5.0, SVM__decision_function_shape=ovr;, score=-0.323 total time=   1.0s
# [CV 5/5] END SVM__C=5.0, SVM__decision_function_shape=ovr;, score=-0.343 total time=   1.0s
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=24, shuffle=True),
#              estimator=Pipeline(steps=[('SCL', MinMaxScaler()),
#                                        ('SVM',
#                                         SVC(kernel='linear', probability=True,
#                                             random_state=24))]),
#              param_grid={'SVM__C': array([1.0000e-03, 2.5005e+00, 5.0000e+00]),
#                          'SVM__decision_function_shape': ['ovo', 'ovr']},
#              scoring='neg_log_loss', verbose=3)

# %%
print(f'Best params: {gcv.best_params_}')
print(f'Best score: {gcv.best_score_}')
# Out:
# Best params: {'SVM__C': 5.0, 'SVM__decision_function_shape': 'ovo'}
# Best score: -0.3385006982938944

# %%
best_model = gcv.best_estimator_
y_pred = best_model.predict(X_test)

# %%
print(accuracy_score(y_test, y_pred))
# Out:
# 0.8653547384774728

# %% [markdown]
# Polynomial GridsearchCV

# %%
svm = SVC(kernel='poly', probability=True,random_state=24)
scale_mm = MinMaxScaler()
pipe = Pipeline([
    ('SCL', scale_mm),
    ('SVM', svm)
])

kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=24)
params = {
    'SVM__C': np.linspace(0.001, 5, 3),
    'SVM__degree': [2,3],
    'SVM__decision_function_shape': ['ovo', 'ovr']
}

gcvp = GridSearchCV(estimator=pipe, param_grid=params, scoring='neg_log_loss', cv=kfold, verbose=3)

# %%
gcvp.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV 1/5] END SVM__C=0.001, SVM__decision_function_shape=ovo, SVM__degree=2;, score=-0.460 total time=   3.4s
# [CV 2/5] END SVM__C=0.001, SVM__decision_function_shape=ovo, SVM__degree=2;, score=-0.455 total time=   3.5s
# [CV 3/5] END SVM__C=0.001, SVM__decision_function_shape=ovo, SVM__degree=2;, score=-0.435 total time=   3.5s
# [CV 4/5] END SVM__C=0.001, SVM__decision_function_shape=ovo, SVM__degree=2;, score=-0.418 total time=   3.6s
# [CV 5/5] END SVM__C=0.001, SVM__decision_function_shape=ovo, SVM__degree=2;, score=-0.455 total time=   3.4s
# [CV 1/5] END SVM__C=0.001, SVM__decision_function_shape=ovo, SVM__degree=3;, score=-0.415 total time=   1.9s
# [CV 2/5] END SVM__C=0.001, SVM__decision_function_shape=ovo, SVM__degree=3;, score=-0.411 total time=   2.0s
# [CV 3/5] END SVM__C=0.001, SVM__decision_function_shape=ovo, SVM__degree=3;, score=-0.399 total time=   1.9s
# [CV 4/5] END SVM__C=0.001, SVM__decision_function_shape=ovo, SVM__degree=3;, score=-0.382 total time=   2.0s
# [CV 5/5] END SVM__C=0.001, SVM__decision_function_shape=ovo, SVM__degree=3;, score=-0.422 total time=   1.9s
# [CV 1/5] END SVM__C=0.001, SVM__decision_function_shape=ovr, SVM__degree=2;, score=-0.460 total time=   3.5s
# [CV 2/5] END SVM__C=0.001, SVM__decision_function_shape=ovr, SVM__degree=2;, score=-0.455 total time=   3.4s
# [CV 3/5] END SVM__C=0.001, SVM__decision_function_shape=ovr, SVM__degree=2;, score=-0.435 total time=   3.5s
# [CV 4/5] END SVM__C=0.001, SVM__decision_function_shape=ovr, SVM__degree=2;, score=-0.418 total time=   3.5s
# [CV 5/5] END SVM__C=0.001, SVM__decision_function_shape=ovr, SVM__degree=2;, score=-0.455 total time=   3.5s
# [CV 1/5] END SVM__C=0.001, SVM__decision_function_shape=ovr, SVM__degree=3;, score=-0.415 total time=   1.9s
# [CV 2/5] END SVM__C=0.001, SVM__decision_function_shape=ovr, SVM__degree=3;, score=-0.411 total time=   1.9s
# [CV 3/5] END SVM__C=0.001, SVM__decision_function_shape=ovr, SVM__degree=3;, score=-0.399 total time=   1.9s
# [CV 4/5] END SVM__C=0.001, SVM__decision_function_shape=ovr, SVM__degree=3;, score=-0.382 total time=   1.9s
# [CV 5/5] END SVM__C=0.001, SVM__decision_function_shape=ovr, SVM__degree=3;, score=-0.422 total time=   2.0s
# [CV 1/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovo, SVM__degree=2;, score=-0.318 total time=   1.3s
# [CV 2/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovo, SVM__degree=2;, score=-0.303 total time=   1.4s
# [CV 3/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovo, SVM__degree=2;, score=-0.288 total time=   1.5s
# [CV 4/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovo, SVM__degree=2;, score=-0.304 total time=   1.5s
# [CV 5/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovo, SVM__degree=2;, score=-0.298 total time=   1.4s
# [CV 1/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovo, SVM__degree=3;, score=-0.317 total time=   3.0s
# [CV 2/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovo, SVM__degree=3;, score=-0.318 total time=   2.7s
# [CV 3/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovo, SVM__degree=3;, score=-0.290 total time=   2.9s
# [CV 4/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovo, SVM__degree=3;, score=-0.302 total time=   2.9s
# [CV 5/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovo, SVM__degree=3;, score=-0.307 total time=   2.7s
# [CV 1/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovr, SVM__degree=2;, score=-0.318 total time=   1.3s
# [CV 2/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovr, SVM__degree=2;, score=-0.303 total time=   1.3s
# [CV 3/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovr, SVM__degree=2;, score=-0.288 total time=   1.3s
# [CV 4/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovr, SVM__degree=2;, score=-0.304 total time=   1.4s
# [CV 5/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovr, SVM__degree=2;, score=-0.298 total time=   1.4s
# [CV 1/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovr, SVM__degree=3;, score=-0.317 total time=   2.9s
# [CV 2/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovr, SVM__degree=3;, score=-0.318 total time=   2.7s
# [CV 3/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovr, SVM__degree=3;, score=-0.290 total time=   3.1s
# [CV 4/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovr, SVM__degree=3;, score=-0.302 total time=   3.1s
# [CV 5/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovr, SVM__degree=3;, score=-0.307 total time=   2.6s
# [CV 1/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__degree=2;, score=-0.315 total time=   1.5s
# [CV 2/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__degree=2;, score=-0.302 total time=   1.5s
# [CV 3/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__degree=2;, score=-0.283 total time=   1.6s
# [CV 4/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__degree=2;, score=-0.300 total time=   1.6s
# [CV 5/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__degree=2;, score=-0.297 total time=   1.6s
# [CV 1/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__degree=3;, score=-0.319 total time=   3.8s
# [CV 2/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__degree=3;, score=-0.319 total time=   3.7s
# [CV 3/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__degree=3;, score=-0.289 total time=   4.2s
# [CV 4/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__degree=3;, score=-0.303 total time=   4.5s
# [CV 5/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__degree=3;, score=-0.310 total time=   3.8s
# [CV 1/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__degree=2;, score=-0.315 total time=   1.5s
# [CV 2/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__degree=2;, score=-0.302 total time=   1.5s
# [CV 3/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__degree=2;, score=-0.283 total time=   1.6s
# [CV 4/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__degree=2;, score=-0.300 total time=   1.6s
# [CV 5/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__degree=2;, score=-0.297 total time=   1.6s
# [CV 1/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__degree=3;, score=-0.319 total time=   4.1s
# [CV 2/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__degree=3;, score=-0.319 total time=   3.8s
# [CV 3/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__degree=3;, score=-0.289 total time=   4.2s
# [CV 4/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__degree=3;, score=-0.303 total time=   4.4s
# [CV 5/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__degree=3;, score=-0.310 total time=   3.8s
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=24, shuffle=True),
#              estimator=Pipeline(steps=[('SCL', MinMaxScaler()),
#                                        ('SVM',
#                                         SVC(kernel='poly', probability=True,
#                                             random_state=24))]),
#              param_grid={'SVM__C': array([1.0000e-03, 2.5005e+00, 5.0000e+00]),
#                          'SVM__decision_function_shape': ['ovo', 'ovr'],
#                          'SVM__degree': [2, 3]},
#              scoring='neg_log_loss', verbose=3)

# %%
print(f'Best params: {gcvp.best_params_}')
print(f'Best score: {gcvp.best_score_}')
# Out:
# Best params: {'SVM__C': 5.0, 'SVM__decision_function_shape': 'ovo', 'SVM__degree': 2}
# Best score: -0.2994729936053615

# %%
best_model = gcvp.best_estimator_
y_pred = best_model.predict(X_test)
print(accuracy_score(y_test, y_pred))
# Out:
# 0.8912480580010357

# %% [markdown]
# Radial GridSearchCV

# %%
svm = SVC(kernel='rbf', probability=True,random_state=24)
scale_mm = MinMaxScaler()
pipe = Pipeline([
    ('SCL', scale_mm),
    ('SVM', svm)
])

kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=24)
params = {
    'SVM__C': np.linspace(0.001, 5, 3),
    'SVM__gamma': np.linspace(0.001, 5, 3),
    'SVM__decision_function_shape': ['ovo', 'ovr']
}

gcvr = GridSearchCV(estimator=pipe, param_grid=params, scoring='neg_log_loss', cv=kfold, verbose=3)

# %%
gcvr.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [CV 1/5] END SVM__C=0.001, SVM__decision_function_shape=ovo, SVM__gamma=0.001;, score=-0.849 total time=  11.0s
# [CV 2/5] END SVM__C=0.001, SVM__decision_function_shape=ovo, SVM__gamma=0.001;, score=-0.867 total time=  10.1s
# [CV 3/5] END SVM__C=0.001, SVM__decision_function_shape=ovo, SVM__gamma=0.001;, score=-0.834 total time=  10.3s
# [CV 4/5] END SVM__C=0.001, SVM__decision_function_shape=ovo, SVM__gamma=0.001;, score=-0.829 total time=  10.0s
# [CV 5/5] END SVM__C=0.001, SVM__decision_function_shape=ovo, SVM__gamma=0.001;, score=-0.834 total time=  10.4s
# [CV 1/5] END SVM__C=0.001, SVM__decision_function_shape=ovo, SVM__gamma=2.5004999999999997;, score=-0.711 total time=  10.3s
# [CV 2/5] END SVM__C=0.001, SVM__decision_function_shape=ovo, SVM__gamma=2.5004999999999997;, score=-0.708 total time=  10.3s
# [CV 3/5] END SVM__C=0.001, SVM__decision_function_shape=ovo, SVM__gamma=2.5004999999999997;, score=-0.672 total time=  10.7s
# [CV 4/5] END SVM__C=0.001, SVM__decision_function_shape=ovo, SVM__gamma=2.5004999999999997;, score=-0.664 total time=  10.1s
# [CV 5/5] END SVM__C=0.001, SVM__decision_function_shape=ovo, SVM__gamma=2.5004999999999997;, score=-0.690 total time=   9.8s
# [CV 1/5] END SVM__C=0.001, SVM__decision_function_shape=ovo, SVM__gamma=5.0;, score=-0.742 total time=  10.4s
# [CV 2/5] END SVM__C=0.001, SVM__decision_function_shape=ovo, SVM__gamma=5.0;, score=-0.740 total time=  10.6s
# [CV 3/5] END SVM__C=0.001, SVM__decision_function_shape=ovo, SVM__gamma=5.0;, score=-0.711 total time=  10.0s
# [CV 4/5] END SVM__C=0.001, SVM__decision_function_shape=ovo, SVM__gamma=5.0;, score=-0.702 total time=   9.9s
# [CV 5/5] END SVM__C=0.001, SVM__decision_function_shape=ovo, SVM__gamma=5.0;, score=-0.721 total time=   9.9s
# [CV 1/5] END SVM__C=0.001, SVM__decision_function_shape=ovr, SVM__gamma=0.001;, score=-0.849 total time=  10.2s
# [CV 2/5] END SVM__C=0.001, SVM__decision_function_shape=ovr, SVM__gamma=0.001;, score=-0.867 total time=  10.6s
# [CV 3/5] END SVM__C=0.001, SVM__decision_function_shape=ovr, SVM__gamma=0.001;, score=-0.834 total time=  10.1s
# [CV 4/5] END SVM__C=0.001, SVM__decision_function_shape=ovr, SVM__gamma=0.001;, score=-0.829 total time=  10.7s
# [CV 5/5] END SVM__C=0.001, SVM__decision_function_shape=ovr, SVM__gamma=0.001;, score=-0.834 total time=  10.1s
# [CV 1/5] END SVM__C=0.001, SVM__decision_function_shape=ovr, SVM__gamma=2.5004999999999997;, score=-0.711 total time=  10.1s
# [CV 2/5] END SVM__C=0.001, SVM__decision_function_shape=ovr, SVM__gamma=2.5004999999999997;, score=-0.708 total time=  10.0s
# [CV 3/5] END SVM__C=0.001, SVM__decision_function_shape=ovr, SVM__gamma=2.5004999999999997;, score=-0.672 total time=  10.8s
# [CV 4/5] END SVM__C=0.001, SVM__decision_function_shape=ovr, SVM__gamma=2.5004999999999997;, score=-0.664 total time=  10.3s
# [CV 5/5] END SVM__C=0.001, SVM__decision_function_shape=ovr, SVM__gamma=2.5004999999999997;, score=-0.690 total time=  10.6s
# [CV 1/5] END SVM__C=0.001, SVM__decision_function_shape=ovr, SVM__gamma=5.0;, score=-0.742 total time=  10.2s
# [CV 2/5] END SVM__C=0.001, SVM__decision_function_shape=ovr, SVM__gamma=5.0;, score=-0.740 total time=  10.8s
# [CV 3/5] END SVM__C=0.001, SVM__decision_function_shape=ovr, SVM__gamma=5.0;, score=-0.711 total time=  10.7s
# [CV 4/5] END SVM__C=0.001, SVM__decision_function_shape=ovr, SVM__gamma=5.0;, score=-0.702 total time=  10.7s
# [CV 5/5] END SVM__C=0.001, SVM__decision_function_shape=ovr, SVM__gamma=5.0;, score=-0.721 total time=  10.2s
# [CV 1/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovo, SVM__gamma=0.001;, score=-0.456 total time=   6.4s
# [CV 2/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovo, SVM__gamma=0.001;, score=-0.449 total time=   6.4s
# [CV 3/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovo, SVM__gamma=0.001;, score=-0.429 total time=   6.5s
# [CV 4/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovo, SVM__gamma=0.001;, score=-0.417 total time=   6.4s
# [CV 5/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovo, SVM__gamma=0.001;, score=-0.449 total time=   6.5s
# [CV 1/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovo, SVM__gamma=2.5004999999999997;, score=-0.252 total time=   2.1s
# [CV 2/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovo, SVM__gamma=2.5004999999999997;, score=-0.251 total time=   2.2s
# [CV 3/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovo, SVM__gamma=2.5004999999999997;, score=-0.202 total time=   2.1s
# [CV 4/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovo, SVM__gamma=2.5004999999999997;, score=-0.237 total time=   2.3s
# [CV 5/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovo, SVM__gamma=2.5004999999999997;, score=-0.235 total time=   2.2s
# [CV 1/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovo, SVM__gamma=5.0;, score=-0.245 total time=   3.3s
# [CV 2/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovo, SVM__gamma=5.0;, score=-0.246 total time=   3.4s
# [CV 3/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovo, SVM__gamma=5.0;, score=-0.207 total time=   3.4s
# [CV 4/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovo, SVM__gamma=5.0;, score=-0.221 total time=   3.4s
# [CV 5/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovo, SVM__gamma=5.0;, score=-0.223 total time=   3.5s
# [CV 1/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovr, SVM__gamma=0.001;, score=-0.456 total time=   6.7s
# [CV 2/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovr, SVM__gamma=0.001;, score=-0.449 total time=   6.5s
# [CV 3/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovr, SVM__gamma=0.001;, score=-0.429 total time=   6.4s
# [CV 4/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovr, SVM__gamma=0.001;, score=-0.417 total time=   6.6s
# [CV 5/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovr, SVM__gamma=0.001;, score=-0.449 total time=   6.7s
# [CV 1/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovr, SVM__gamma=2.5004999999999997;, score=-0.252 total time=   2.1s
# [CV 2/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovr, SVM__gamma=2.5004999999999997;, score=-0.251 total time=   2.2s
# [CV 3/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovr, SVM__gamma=2.5004999999999997;, score=-0.202 total time=   2.1s
# [CV 4/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovr, SVM__gamma=2.5004999999999997;, score=-0.237 total time=   2.3s
# [CV 5/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovr, SVM__gamma=2.5004999999999997;, score=-0.235 total time=   2.2s
# [CV 1/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovr, SVM__gamma=5.0;, score=-0.245 total time=   3.4s
# [CV 2/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovr, SVM__gamma=5.0;, score=-0.246 total time=   3.5s
# [CV 3/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovr, SVM__gamma=5.0;, score=-0.207 total time=   3.7s
# [CV 4/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovr, SVM__gamma=5.0;, score=-0.221 total time=   3.6s
# [CV 5/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovr, SVM__gamma=5.0;, score=-0.223 total time=   3.7s
# [CV 1/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=0.001;, score=-0.436 total time=   6.1s
# [CV 2/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=0.001;, score=-0.431 total time=   6.0s
# [CV 3/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=0.001;, score=-0.406 total time=   6.3s
# [CV 4/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=0.001;, score=-0.396 total time=   6.2s
# [CV 5/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=0.001;, score=-0.434 total time=   6.1s
# [CV 1/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=2.5004999999999997;, score=-0.242 total time=   2.4s
# [CV 2/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=2.5004999999999997;, score=-0.244 total time=   2.5s
# [CV 3/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=2.5004999999999997;, score=-0.202 total time=   2.4s
# [CV 4/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=2.5004999999999997;, score=-0.228 total time=   2.4s
# [CV 5/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=2.5004999999999997;, score=-0.227 total time=   2.3s
# [CV 1/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=5.0;, score=-0.243 total time=   3.7s
# [CV 2/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=5.0;, score=-0.246 total time=   3.8s
# [CV 3/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=5.0;, score=-0.208 total time=   3.7s
# [CV 4/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=5.0;, score=-0.219 total time=   3.6s
# [CV 5/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=5.0;, score=-0.224 total time=   3.5s
# [CV 1/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=0.001;, score=-0.436 total time=   5.5s
# [CV 2/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=0.001;, score=-0.431 total time=   5.3s
# [CV 3/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=0.001;, score=-0.406 total time=   5.7s
# [CV 4/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=0.001;, score=-0.396 total time=   5.4s
# [CV 5/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=0.001;, score=-0.434 total time=   5.4s
# [CV 1/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=2.5004999999999997;, score=-0.242 total time=   2.2s
# [CV 2/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=2.5004999999999997;, score=-0.244 total time=   2.3s
# [CV 3/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=2.5004999999999997;, score=-0.202 total time=   2.2s
# [CV 4/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=2.5004999999999997;, score=-0.228 total time=   2.3s
# [CV 5/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=2.5004999999999997;, score=-0.227 total time=   2.2s
# [CV 1/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=5.0;, score=-0.243 total time=   3.8s
# [CV 2/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=5.0;, score=-0.246 total time=   3.7s
# [CV 3/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=5.0;, score=-0.208 total time=   3.5s
# [CV 4/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=5.0;, score=-0.219 total time=   3.6s
# [CV 5/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=5.0;, score=-0.224 total time=   3.6s
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=24, shuffle=True),
#              estimator=Pipeline(steps=[('SCL', MinMaxScaler()),
#                                        ('SVM',
#                                         SVC(probability=True,
#                                             random_state=24))]),
#              param_grid={'SVM__C': array([1.0000e-03, 2.5005e+00, 5.0000e+00]),
#                          'SVM__decision_function_shape': ['ovo', 'ovr'],
#                          'SVM__gamma': array([1.0000e-03, 2.5005e+00, 5.0000e+00])},
#              scoring='neg_log_loss', verbose=3)

# %%
print(f'Best params: {gcvr.best_params_}')
print(f'Best score: {gcvr.best_score_}')
# Out:
# Best params: {'SVM__C': 5.0, 'SVM__decision_function_shape': 'ovo', 'SVM__gamma': 5.0}
# Best score: -0.2280545577407247

# %%
best_model = gcvr.best_estimator_
y_pred = best_model.predict(X_test)
print(accuracy_score(y_test, y_pred))
# Out:
# 0.9228379078197825
